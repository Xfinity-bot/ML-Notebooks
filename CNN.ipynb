# %% [markdown]
# <a href="https://colab.research.google.com/github/Xfinity-bot/ML-Notebooks/blob/main/CNN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder

from keras.models import Sequential
from keras.layers import Dense
from keras.optimizers import Adam

iris_data = load_iris() # load the iris dataset

print('Example data: ')
print(iris_data.data[:5])
print('Example labels: ')
print(iris_data.target[:5])

x = iris_data.data
y_ = iris_data.target.reshape(-1, 1) # Convert data to a single column

# One Hot encode the class labels
encoder = OneHotEncoder(sparse=False)
y = encoder.fit_transform(y_)
#print(y)

# Split the data for training and testing
train_x, test_x, train_y, test_y = train_test_split(x, y, test_size=0.20)

# Build the model

model = Sequential()

model.add(Dense(10, input_shape=(4,), activation='relu', name='fc1'))
model.add(Dense(10, activation='relu', name='fc2'))
model.add(Dense(3, activation='softmax', name='output'))

# Adam optimizer with learning rate of 0.001
optimizer = Adam(lr=0.001)
model.compile(optimizer, loss='categorical_crossentropy', metrics=['accuracy'])

print('Neural Network Model Summary: ')
print(model.summary())

# Train the model
model.fit(train_x, train_y, verbose=2, batch_size=5, epochs=200)

# Test on unseen data

results = model.evaluate(test_x, test_y)

print('Final test set loss: {:4f}'.format(results[0]))
print('Final test set accuracy: {:4f}'.format(results[1]))
# Out:
# Example data:
# [[5.1 3.5 1.4 0.2]
#  [4.9 3.  1.4 0.2]
#  [4.7 3.2 1.3 0.2]
#  [4.6 3.1 1.5 0.2]
#  [5.  3.6 1.4 0.2]]
# Example labels:
# [0 0 0 0 0]
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# Neural Network Model Summary:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  fc1 (Dense)                 (None, 10)                50
#
#  fc2 (Dense)                 (None, 10)                110
#
#  output (Dense)              (None, 3)                 33
#
# =================================================================
# Total params: 193
# Trainable params: 193
# Non-trainable params: 0
# _________________________________________________________________
# /usr/local/lib/python3.10/dist-packages/keras/optimizers/legacy/adam.py:117: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)
# None
# Epoch 1/200
# 24/24 - 3s - loss: 1.2448 - accuracy: 0.3083 - 3s/epoch - 105ms/step
# Epoch 2/200
# 24/24 - 0s - loss: 1.0997 - accuracy: 0.3083 - 89ms/epoch - 4ms/step
# Epoch 3/200
# 24/24 - 0s - loss: 0.9755 - accuracy: 0.5833 - 94ms/epoch - 4ms/step
# Epoch 4/200
# 24/24 - 0s - loss: 0.9116 - accuracy: 0.6833 - 70ms/epoch - 3ms/step
# Epoch 5/200
# 24/24 - 0s - loss: 0.8599 - accuracy: 0.8750 - 67ms/epoch - 3ms/step
# Epoch 6/200
# 24/24 - 0s - loss: 0.8108 - accuracy: 0.8833 - 81ms/epoch - 3ms/step
# Epoch 7/200
# 24/24 - 0s - loss: 0.7593 - accuracy: 0.8000 - 133ms/epoch - 6ms/step
# Epoch 8/200
# 24/24 - 0s - loss: 0.7087 - accuracy: 0.7333 - 57ms/epoch - 2ms/step
# Epoch 9/200
# 24/24 - 0s - loss: 0.6631 - accuracy: 0.6917 - 67ms/epoch - 3ms/step
# Epoch 10/200
# 24/24 - 0s - loss: 0.6187 - accuracy: 0.7000 - 64ms/epoch - 3ms/step
# Epoch 11/200
# 24/24 - 0s - loss: 0.5814 - accuracy: 0.7167 - 103ms/epoch - 4ms/step
# Epoch 12/200
# 24/24 - 0s - loss: 0.5479 - accuracy: 0.7583 - 142ms/epoch - 6ms/step
# Epoch 13/200
# 24/24 - 0s - loss: 0.5120 - accuracy: 0.7333 - 62ms/epoch - 3ms/step
# Epoch 14/200
# 24/24 - 0s - loss: 0.4824 - accuracy: 0.7833 - 81ms/epoch - 3ms/step
# Epoch 15/200
# 24/24 - 0s - loss: 0.4543 - accuracy: 0.8667 - 79ms/epoch - 3ms/step
# Epoch 16/200
# 24/24 - 0s - loss: 0.4321 - accuracy: 0.8750 - 130ms/epoch - 5ms/step
# Epoch 17/200
# 24/24 - 0s - loss: 0.4120 - accuracy: 0.9333 - 121ms/epoch - 5ms/step
# Epoch 18/200
# 24/24 - 0s - loss: 0.3927 - accuracy: 0.9083 - 129ms/epoch - 5ms/step
# Epoch 19/200
# 24/24 - 0s - loss: 0.3757 - accuracy: 0.9417 - 141ms/epoch - 6ms/step
# Epoch 20/200
# 24/24 - 0s - loss: 0.3650 - accuracy: 0.9000 - 115ms/epoch - 5ms/step
# Epoch 21/200
# 24/24 - 0s - loss: 0.3454 - accuracy: 0.9583 - 91ms/epoch - 4ms/step
# Epoch 22/200
# 24/24 - 0s - loss: 0.3283 - accuracy: 0.9583 - 69ms/epoch - 3ms/step
# Epoch 23/200
# 24/24 - 0s - loss: 0.3157 - accuracy: 0.9333 - 198ms/epoch - 8ms/step
# Epoch 24/200
# 24/24 - 0s - loss: 0.3058 - accuracy: 0.9500 - 86ms/epoch - 4ms/step
# Epoch 25/200
# 24/24 - 0s - loss: 0.2894 - accuracy: 0.9417 - 122ms/epoch - 5ms/step
# Epoch 26/200
# 24/24 - 0s - loss: 0.2781 - accuracy: 0.9583 - 92ms/epoch - 4ms/step
# Epoch 27/200
# 24/24 - 0s - loss: 0.2673 - accuracy: 0.9667 - 123ms/epoch - 5ms/step
# Epoch 28/200
# 24/24 - 0s - loss: 0.2544 - accuracy: 0.9750 - 147ms/epoch - 6ms/step
# Epoch 29/200
# 24/24 - 0s - loss: 0.2459 - accuracy: 0.9583 - 295ms/epoch - 12ms/step
# Epoch 30/200
# 24/24 - 0s - loss: 0.2396 - accuracy: 0.9750 - 163ms/epoch - 7ms/step
# Epoch 31/200
# 24/24 - 0s - loss: 0.2294 - accuracy: 0.9667 - 116ms/epoch - 5ms/step
# Epoch 32/200
# 24/24 - 0s - loss: 0.2245 - accuracy: 0.9667 - 111ms/epoch - 5ms/step
# Epoch 33/200
# 24/24 - 0s - loss: 0.2109 - accuracy: 0.9667 - 122ms/epoch - 5ms/step
# Epoch 34/200
# 24/24 - 0s - loss: 0.2036 - accuracy: 0.9667 - 100ms/epoch - 4ms/step
# Epoch 35/200
# 24/24 - 0s - loss: 0.2035 - accuracy: 0.9583 - 114ms/epoch - 5ms/step
# Epoch 36/200
# 24/24 - 0s - loss: 0.1955 - accuracy: 0.9750 - 132ms/epoch - 5ms/step
# Epoch 37/200
# 24/24 - 0s - loss: 0.1845 - accuracy: 0.9750 - 158ms/epoch - 7ms/step
# Epoch 38/200
# 24/24 - 0s - loss: 0.1798 - accuracy: 0.9667 - 135ms/epoch - 6ms/step
# Epoch 39/200
# 24/24 - 0s - loss: 0.1928 - accuracy: 0.9583 - 113ms/epoch - 5ms/step
# Epoch 40/200
# 24/24 - 0s - loss: 0.1688 - accuracy: 0.9750 - 111ms/epoch - 5ms/step
# Epoch 41/200
# 24/24 - 0s - loss: 0.1675 - accuracy: 0.9583 - 103ms/epoch - 4ms/step
# Epoch 42/200
# 24/24 - 0s - loss: 0.1595 - accuracy: 0.9750 - 118ms/epoch - 5ms/step
# Epoch 43/200
# 24/24 - 0s - loss: 0.1582 - accuracy: 0.9583 - 145ms/epoch - 6ms/step
# Epoch 44/200
# 24/24 - 0s - loss: 0.1581 - accuracy: 0.9583 - 86ms/epoch - 4ms/step
# Epoch 45/200
# 24/24 - 0s - loss: 0.1579 - accuracy: 0.9583 - 112ms/epoch - 5ms/step
# Epoch 46/200
# 24/24 - 0s - loss: 0.1478 - accuracy: 0.9750 - 135ms/epoch - 6ms/step
# Epoch 47/200
# 24/24 - 0s - loss: 0.1406 - accuracy: 0.9750 - 130ms/epoch - 5ms/step
# Epoch 48/200
# 24/24 - 0s - loss: 0.1378 - accuracy: 0.9750 - 72ms/epoch - 3ms/step
# Epoch 49/200
# 24/24 - 0s - loss: 0.1365 - accuracy: 0.9750 - 83ms/epoch - 3ms/step
# Epoch 50/200
# 24/24 - 0s - loss: 0.1352 - accuracy: 0.9667 - 63ms/epoch - 3ms/step
# Epoch 51/200
# 24/24 - 0s - loss: 0.1315 - accuracy: 0.9667 - 60ms/epoch - 2ms/step
# Epoch 52/200
# 24/24 - 0s - loss: 0.1295 - accuracy: 0.9667 - 53ms/epoch - 2ms/step
# Epoch 53/200
# 24/24 - 0s - loss: 0.1302 - accuracy: 0.9667 - 53ms/epoch - 2ms/step
# Epoch 54/200
# 24/24 - 0s - loss: 0.1215 - accuracy: 0.9833 - 55ms/epoch - 2ms/step
# Epoch 55/200
# 24/24 - 0s - loss: 0.1251 - accuracy: 0.9750 - 77ms/epoch - 3ms/step
# Epoch 56/200
# 24/24 - 0s - loss: 0.1199 - accuracy: 0.9667 - 110ms/epoch - 5ms/step
# Epoch 57/200
# 24/24 - 0s - loss: 0.1174 - accuracy: 0.9750 - 73ms/epoch - 3ms/step
# Epoch 58/200
# 24/24 - 0s - loss: 0.1160 - accuracy: 0.9750 - 55ms/epoch - 2ms/step
# Epoch 59/200
# 24/24 - 0s - loss: 0.1133 - accuracy: 0.9667 - 54ms/epoch - 2ms/step
# Epoch 60/200
# 24/24 - 0s - loss: 0.1122 - accuracy: 0.9750 - 71ms/epoch - 3ms/step
# Epoch 61/200
# 24/24 - 0s - loss: 0.1084 - accuracy: 0.9750 - 63ms/epoch - 3ms/step
# Epoch 62/200
# 24/24 - 0s - loss: 0.1136 - accuracy: 0.9500 - 55ms/epoch - 2ms/step
# Epoch 63/200
# 24/24 - 0s - loss: 0.1065 - accuracy: 0.9750 - 84ms/epoch - 4ms/step
# Epoch 64/200
# 24/24 - 0s - loss: 0.1043 - accuracy: 0.9750 - 89ms/epoch - 4ms/step
# Epoch 65/200
# 24/24 - 0s - loss: 0.1048 - accuracy: 0.9750 - 93ms/epoch - 4ms/step
# Epoch 66/200
# 24/24 - 0s - loss: 0.1004 - accuracy: 0.9750 - 94ms/epoch - 4ms/step
# Epoch 67/200
# 24/24 - 0s - loss: 0.0959 - accuracy: 0.9750 - 87ms/epoch - 4ms/step
# Epoch 68/200
# 24/24 - 0s - loss: 0.0976 - accuracy: 0.9833 - 123ms/epoch - 5ms/step
# Epoch 69/200
# 24/24 - 0s - loss: 0.0941 - accuracy: 0.9750 - 66ms/epoch - 3ms/step
# Epoch 70/200
# 24/24 - 0s - loss: 0.0997 - accuracy: 0.9750 - 74ms/epoch - 3ms/step
# Epoch 71/200
# 24/24 - 0s - loss: 0.0917 - accuracy: 0.9833 - 102ms/epoch - 4ms/step
# Epoch 72/200
# 24/24 - 0s - loss: 0.0914 - accuracy: 0.9750 - 62ms/epoch - 3ms/step
# Epoch 73/200
# 24/24 - 0s - loss: 0.0896 - accuracy: 0.9833 - 81ms/epoch - 3ms/step
# Epoch 74/200
# 24/24 - 0s - loss: 0.0891 - accuracy: 0.9750 - 73ms/epoch - 3ms/step
# Epoch 75/200
# 24/24 - 0s - loss: 0.0892 - accuracy: 0.9750 - 85ms/epoch - 4ms/step
# Epoch 76/200
# 24/24 - 0s - loss: 0.0879 - accuracy: 0.9833 - 61ms/epoch - 3ms/step
# Epoch 77/200
# 24/24 - 0s - loss: 0.0866 - accuracy: 0.9833 - 59ms/epoch - 2ms/step
# Epoch 78/200
# 24/24 - 0s - loss: 0.0863 - accuracy: 0.9833 - 80ms/epoch - 3ms/step
# Epoch 79/200
# 24/24 - 0s - loss: 0.0862 - accuracy: 0.9833 - 150ms/epoch - 6ms/step
# Epoch 80/200
# 24/24 - 0s - loss: 0.0858 - accuracy: 0.9750 - 146ms/epoch - 6ms/step
# Epoch 81/200
# 24/24 - 0s - loss: 0.0854 - accuracy: 0.9833 - 120ms/epoch - 5ms/step
# Epoch 82/200
# 24/24 - 0s - loss: 0.0822 - accuracy: 0.9833 - 80ms/epoch - 3ms/step
# Epoch 83/200
# 24/24 - 0s - loss: 0.0900 - accuracy: 0.9833 - 115ms/epoch - 5ms/step
# Epoch 84/200
# 24/24 - 0s - loss: 0.0854 - accuracy: 0.9833 - 140ms/epoch - 6ms/step
# Epoch 85/200
# 24/24 - 0s - loss: 0.0835 - accuracy: 0.9833 - 122ms/epoch - 5ms/step
# Epoch 86/200
# 24/24 - 0s - loss: 0.0843 - accuracy: 0.9750 - 108ms/epoch - 4ms/step
# Epoch 87/200
# 24/24 - 0s - loss: 0.0823 - accuracy: 0.9750 - 118ms/epoch - 5ms/step
# Epoch 88/200
# 24/24 - 0s - loss: 0.0781 - accuracy: 0.9833 - 141ms/epoch - 6ms/step
# Epoch 89/200
# 24/24 - 0s - loss: 0.0789 - accuracy: 0.9750 - 158ms/epoch - 7ms/step
# Epoch 90/200
# 24/24 - 0s - loss: 0.0790 - accuracy: 0.9833 - 98ms/epoch - 4ms/step
# Epoch 91/200
# 24/24 - 0s - loss: 0.0823 - accuracy: 0.9833 - 66ms/epoch - 3ms/step
# Epoch 92/200
# 24/24 - 0s - loss: 0.0805 - accuracy: 0.9750 - 75ms/epoch - 3ms/step
# Epoch 93/200
# 24/24 - 0s - loss: 0.0790 - accuracy: 0.9833 - 102ms/epoch - 4ms/step
# Epoch 94/200
# 24/24 - 0s - loss: 0.0762 - accuracy: 0.9833 - 129ms/epoch - 5ms/step
# Epoch 95/200
# 24/24 - 0s - loss: 0.0770 - accuracy: 0.9833 - 168ms/epoch - 7ms/step
# Epoch 96/200
# 24/24 - 0s - loss: 0.0766 - accuracy: 0.9833 - 123ms/epoch - 5ms/step
# Epoch 97/200
# 24/24 - 0s - loss: 0.0775 - accuracy: 0.9750 - 152ms/epoch - 6ms/step
# Epoch 98/200
# 24/24 - 0s - loss: 0.0781 - accuracy: 0.9833 - 152ms/epoch - 6ms/step
# Epoch 99/200
# 24/24 - 0s - loss: 0.0803 - accuracy: 0.9833 - 116ms/epoch - 5ms/step
# Epoch 100/200
# 24/24 - 0s - loss: 0.0759 - accuracy: 0.9833 - 119ms/epoch - 5ms/step
# Epoch 101/200
# 24/24 - 0s - loss: 0.0728 - accuracy: 0.9750 - 113ms/epoch - 5ms/step
# Epoch 102/200
# 24/24 - 0s - loss: 0.0758 - accuracy: 0.9750 - 125ms/epoch - 5ms/step
# Epoch 103/200
# 24/24 - 0s - loss: 0.0757 - accuracy: 0.9833 - 73ms/epoch - 3ms/step
# Epoch 104/200
# 24/24 - 0s - loss: 0.0786 - accuracy: 0.9750 - 75ms/epoch - 3ms/step
# Epoch 105/200
# 24/24 - 0s - loss: 0.0736 - accuracy: 0.9833 - 72ms/epoch - 3ms/step
# Epoch 106/200
# 24/24 - 0s - loss: 0.0742 - accuracy: 0.9750 - 84ms/epoch - 4ms/step
# Epoch 107/200
# 24/24 - 0s - loss: 0.0722 - accuracy: 0.9833 - 69ms/epoch - 3ms/step
# Epoch 108/200
# 24/24 - 0s - loss: 0.0722 - accuracy: 0.9833 - 69ms/epoch - 3ms/step
# Epoch 109/200
# 24/24 - 0s - loss: 0.0736 - accuracy: 0.9833 - 87ms/epoch - 4ms/step
# Epoch 110/200
# 24/24 - 0s - loss: 0.0746 - accuracy: 0.9833 - 88ms/epoch - 4ms/step
# Epoch 111/200
# 24/24 - 0s - loss: 0.0710 - accuracy: 0.9833 - 57ms/epoch - 2ms/step
# Epoch 112/200
# 24/24 - 0s - loss: 0.0746 - accuracy: 0.9750 - 70ms/epoch - 3ms/step
# Epoch 113/200
# 24/24 - 0s - loss: 0.0710 - accuracy: 0.9833 - 95ms/epoch - 4ms/step
# Epoch 114/200
# 24/24 - 0s - loss: 0.0793 - accuracy: 0.9667 - 95ms/epoch - 4ms/step
# Epoch 115/200
# 24/24 - 0s - loss: 0.0695 - accuracy: 0.9833 - 78ms/epoch - 3ms/step
# Epoch 116/200
# 24/24 - 0s - loss: 0.0709 - accuracy: 0.9750 - 96ms/epoch - 4ms/step
# Epoch 117/200
# 24/24 - 0s - loss: 0.0748 - accuracy: 0.9750 - 65ms/epoch - 3ms/step
# Epoch 118/200
# 24/24 - 0s - loss: 0.0732 - accuracy: 0.9750 - 58ms/epoch - 2ms/step
# Epoch 119/200
# 24/24 - 0s - loss: 0.0728 - accuracy: 0.9833 - 107ms/epoch - 4ms/step
# Epoch 120/200
# 24/24 - 0s - loss: 0.0692 - accuracy: 0.9750 - 83ms/epoch - 3ms/step
# Epoch 121/200
# 24/24 - 0s - loss: 0.0767 - accuracy: 0.9750 - 86ms/epoch - 4ms/step
# Epoch 122/200
# 24/24 - 0s - loss: 0.0743 - accuracy: 0.9833 - 59ms/epoch - 2ms/step
# Epoch 123/200
# 24/24 - 0s - loss: 0.0701 - accuracy: 0.9833 - 87ms/epoch - 4ms/step
# Epoch 124/200
# 24/24 - 0s - loss: 0.0709 - accuracy: 0.9750 - 84ms/epoch - 4ms/step
# Epoch 125/200
# 24/24 - 0s - loss: 0.0685 - accuracy: 0.9833 - 76ms/epoch - 3ms/step
# Epoch 126/200
# 24/24 - 0s - loss: 0.0697 - accuracy: 0.9833 - 92ms/epoch - 4ms/step
# Epoch 127/200
# 24/24 - 0s - loss: 0.0691 - accuracy: 0.9833 - 52ms/epoch - 2ms/step
# Epoch 128/200
# 24/24 - 0s - loss: 0.0686 - accuracy: 0.9750 - 48ms/epoch - 2ms/step
# Epoch 129/200
# 24/24 - 0s - loss: 0.0692 - accuracy: 0.9750 - 49ms/epoch - 2ms/step
# Epoch 130/200
# 24/24 - 0s - loss: 0.0733 - accuracy: 0.9750 - 69ms/epoch - 3ms/step
# Epoch 131/200
# 24/24 - 0s - loss: 0.0647 - accuracy: 0.9833 - 57ms/epoch - 2ms/step
# Epoch 132/200
# 24/24 - 0s - loss: 0.0697 - accuracy: 0.9833 - 56ms/epoch - 2ms/step
# Epoch 133/200
# 24/24 - 0s - loss: 0.0683 - accuracy: 0.9833 - 73ms/epoch - 3ms/step
# Epoch 134/200
# 24/24 - 0s - loss: 0.0653 - accuracy: 0.9833 - 62ms/epoch - 3ms/step
# Epoch 135/200
# 24/24 - 0s - loss: 0.0686 - accuracy: 0.9833 - 98ms/epoch - 4ms/step
# Epoch 136/200
# 24/24 - 0s - loss: 0.0681 - accuracy: 0.9750 - 72ms/epoch - 3ms/step
# Epoch 137/200
# 24/24 - 0s - loss: 0.0678 - accuracy: 0.9833 - 96ms/epoch - 4ms/step
# Epoch 138/200
# 24/24 - 0s - loss: 0.0665 - accuracy: 0.9833 - 113ms/epoch - 5ms/step
# Epoch 139/200
# 24/24 - 0s - loss: 0.0653 - accuracy: 0.9833 - 65ms/epoch - 3ms/step
# Epoch 140/200
# 24/24 - 0s - loss: 0.0649 - accuracy: 0.9833 - 54ms/epoch - 2ms/step
# Epoch 141/200
# 24/24 - 0s - loss: 0.0724 - accuracy: 0.9833 - 94ms/epoch - 4ms/step
# Epoch 142/200
# 24/24 - 0s - loss: 0.0668 - accuracy: 0.9833 - 70ms/epoch - 3ms/step
# Epoch 143/200
# 24/24 - 0s - loss: 0.0657 - accuracy: 0.9750 - 68ms/epoch - 3ms/step
# Epoch 144/200
# 24/24 - 0s - loss: 0.0639 - accuracy: 0.9833 - 72ms/epoch - 3ms/step
# Epoch 145/200
# 24/24 - 0s - loss: 0.0658 - accuracy: 0.9833 - 82ms/epoch - 3ms/step
# Epoch 146/200
# 24/24 - 0s - loss: 0.0672 - accuracy: 0.9750 - 84ms/epoch - 3ms/step
# Epoch 147/200
# 24/24 - 0s - loss: 0.0635 - accuracy: 0.9833 - 66ms/epoch - 3ms/step
# Epoch 148/200
# 24/24 - 0s - loss: 0.0659 - accuracy: 0.9833 - 91ms/epoch - 4ms/step
# Epoch 149/200
# 24/24 - 0s - loss: 0.0645 - accuracy: 0.9833 - 60ms/epoch - 3ms/step
# Epoch 150/200
# 24/24 - 0s - loss: 0.0658 - accuracy: 0.9750 - 51ms/epoch - 2ms/step
# Epoch 151/200
# 24/24 - 0s - loss: 0.0659 - accuracy: 0.9667 - 133ms/epoch - 6ms/step
# Epoch 152/200
# 24/24 - 0s - loss: 0.0658 - accuracy: 0.9833 - 76ms/epoch - 3ms/step
# Epoch 153/200
# 24/24 - 0s - loss: 0.0662 - accuracy: 0.9833 - 65ms/epoch - 3ms/step
# Epoch 154/200
# 24/24 - 0s - loss: 0.0613 - accuracy: 0.9833 - 55ms/epoch - 2ms/step
# Epoch 155/200
# 24/24 - 0s - loss: 0.0656 - accuracy: 0.9750 - 63ms/epoch - 3ms/step
# Epoch 156/200
# 24/24 - 0s - loss: 0.0677 - accuracy: 0.9833 - 98ms/epoch - 4ms/step
# Epoch 157/200
# 24/24 - 0s - loss: 0.0629 - accuracy: 0.9750 - 69ms/epoch - 3ms/step
# Epoch 158/200
# 24/24 - 0s - loss: 0.0644 - accuracy: 0.9833 - 65ms/epoch - 3ms/step
# Epoch 159/200
# 24/24 - 0s - loss: 0.0645 - accuracy: 0.9833 - 65ms/epoch - 3ms/step
# Epoch 160/200
# 24/24 - 0s - loss: 0.0636 - accuracy: 0.9833 - 54ms/epoch - 2ms/step
# Epoch 161/200
# 24/24 - 0s - loss: 0.0654 - accuracy: 0.9833 - 122ms/epoch - 5ms/step
# Epoch 162/200
# 24/24 - 0s - loss: 0.0657 - accuracy: 0.9833 - 76ms/epoch - 3ms/step
# Epoch 163/200
# 24/24 - 0s - loss: 0.0765 - accuracy: 0.9750 - 112ms/epoch - 5ms/step
# Epoch 164/200
# 24/24 - 0s - loss: 0.0658 - accuracy: 0.9917 - 69ms/epoch - 3ms/step
# Epoch 165/200
# 24/24 - 0s - loss: 0.0650 - accuracy: 0.9833 - 107ms/epoch - 4ms/step
# Epoch 166/200
# 24/24 - 0s - loss: 0.0662 - accuracy: 0.9833 - 104ms/epoch - 4ms/step
# Epoch 167/200
# 24/24 - 0s - loss: 0.0612 - accuracy: 0.9833 - 74ms/epoch - 3ms/step
# Epoch 168/200
# 24/24 - 0s - loss: 0.0617 - accuracy: 0.9833 - 77ms/epoch - 3ms/step
# Epoch 169/200
# 24/24 - 0s - loss: 0.0653 - accuracy: 0.9833 - 54ms/epoch - 2ms/step
# Epoch 170/200
# 24/24 - 0s - loss: 0.0656 - accuracy: 0.9750 - 48ms/epoch - 2ms/step
# Epoch 171/200
# 24/24 - 0s - loss: 0.0623 - accuracy: 0.9750 - 47ms/epoch - 2ms/step
# Epoch 172/200
# 24/24 - 0s - loss: 0.0603 - accuracy: 0.9833 - 40ms/epoch - 2ms/step
# Epoch 173/200
# 24/24 - 0s - loss: 0.0646 - accuracy: 0.9667 - 42ms/epoch - 2ms/step
# Epoch 174/200
# 24/24 - 0s - loss: 0.0626 - accuracy: 0.9833 - 41ms/epoch - 2ms/step
# Epoch 175/200
# 24/24 - 0s - loss: 0.0635 - accuracy: 0.9833 - 41ms/epoch - 2ms/step
# Epoch 176/200
# 24/24 - 0s - loss: 0.0666 - accuracy: 0.9750 - 41ms/epoch - 2ms/step
# Epoch 177/200
# 24/24 - 0s - loss: 0.0660 - accuracy: 0.9750 - 40ms/epoch - 2ms/step
# Epoch 178/200
# 24/24 - 0s - loss: 0.0616 - accuracy: 0.9833 - 41ms/epoch - 2ms/step
# Epoch 179/200
# 24/24 - 0s - loss: 0.0655 - accuracy: 0.9833 - 43ms/epoch - 2ms/step
# Epoch 180/200
# 24/24 - 0s - loss: 0.0632 - accuracy: 0.9833 - 42ms/epoch - 2ms/step
# Epoch 181/200
# 24/24 - 0s - loss: 0.0648 - accuracy: 0.9833 - 42ms/epoch - 2ms/step
# Epoch 182/200
# 24/24 - 0s - loss: 0.0635 - accuracy: 0.9750 - 41ms/epoch - 2ms/step
# Epoch 183/200
# 24/24 - 0s - loss: 0.0602 - accuracy: 0.9833 - 39ms/epoch - 2ms/step
# Epoch 184/200
# 24/24 - 0s - loss: 0.0624 - accuracy: 0.9833 - 39ms/epoch - 2ms/step
# Epoch 185/200
# 24/24 - 0s - loss: 0.0721 - accuracy: 0.9667 - 39ms/epoch - 2ms/step
# Epoch 186/200
# 24/24 - 0s - loss: 0.0725 - accuracy: 0.9750 - 49ms/epoch - 2ms/step
# Epoch 187/200
# 24/24 - 0s - loss: 0.0566 - accuracy: 0.9833 - 45ms/epoch - 2ms/step
# Epoch 188/200
# 24/24 - 0s - loss: 0.0630 - accuracy: 0.9833 - 48ms/epoch - 2ms/step
# Epoch 189/200
# 24/24 - 0s - loss: 0.0712 - accuracy: 0.9750 - 40ms/epoch - 2ms/step
# Epoch 190/200
# 24/24 - 0s - loss: 0.0620 - accuracy: 0.9667 - 40ms/epoch - 2ms/step
# Epoch 191/200
# 24/24 - 0s - loss: 0.0596 - accuracy: 0.9833 - 39ms/epoch - 2ms/step
# Epoch 192/200
# 24/24 - 0s - loss: 0.0661 - accuracy: 0.9750 - 40ms/epoch - 2ms/step
# Epoch 193/200
# 24/24 - 0s - loss: 0.0633 - accuracy: 0.9833 - 48ms/epoch - 2ms/step
# Epoch 194/200
# 24/24 - 0s - loss: 0.0695 - accuracy: 0.9667 - 38ms/epoch - 2ms/step
# Epoch 195/200
# 24/24 - 0s - loss: 0.0594 - accuracy: 0.9833 - 42ms/epoch - 2ms/step
# Epoch 196/200
# 24/24 - 0s - loss: 0.0578 - accuracy: 0.9833 - 55ms/epoch - 2ms/step
# Epoch 197/200
# 24/24 - 0s - loss: 0.0648 - accuracy: 0.9667 - 42ms/epoch - 2ms/step
# Epoch 198/200
# 24/24 - 0s - loss: 0.0617 - accuracy: 0.9833 - 40ms/epoch - 2ms/step
# Epoch 199/200
# 24/24 - 0s - loss: 0.0616 - accuracy: 0.9833 - 40ms/epoch - 2ms/step
# Epoch 200/200
# 24/24 - 0s - loss: 0.0621 - accuracy: 0.9833 - 40ms/epoch - 2ms/step
# 1/1 [==============================] - 0s 186ms/step - loss: 0.0685 - accuracy: 1.0000
# Final test set loss: 0.068470
# Final test set accuracy: 1.000000
